# %%
import numpy as np
import pandas as pd

# %%
cd
# Out:
# C:\Users\user

# %%
cd desktop
# Out:
# C:\Users\user\desktop

# %%
cd python
# Out:
# C:\Users\user\desktop\python

# %%
cd imarticus
# Out:
# C:\Users\user\desktop\python\imarticus

# %%
lend = pd.read_excel('Lending Data.xlsx')

# %%
lend
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 0                                                 NaN      NaN   -1        -2
# 1                               American Express Co.       NY     1   0.23829
# 2                            First Citizens Banchares      NC     2  0.187393
# 3                            Wintrust Financial Corp.      IL     3  0.168999
# 4                                       Zions Bancorp      UT     4  0.117973
# ..                                                ...      ...  ...       ...
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
# ...

# %%
df = pd.DataFrame(lend)

# %%
df.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Unnamed: 10  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0          NaN               -9.0      -10.0           -11
# ...

# %%
df1 = df.fillna(0)

# %%
df1['Rank'] = df1['Rank'].replace(regex = True, to_replace = '[A-Z]', value = 0)# ranking can't be in negative it can be either 0 or above

# %%
df1['Rank'][df1['Rank'] < 0] = 0
df1
# Out:
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                           Name of Lending Institution HQ State  Rank  \
# 0                                                   0        0     0
# 1                               American Express Co.       NY      1
# 2                            First Citizens Banchares      NC      2
# 3                            Wintrust Financial Corp.      IL      3
# 4                                       Zions Bancorp      UT      4
# ..                                                ...      ...   ...
# 92                     Charles Schwab Bk                    NV     0
# ...

# %%
df1['Lender Asset Size'].unique()
# Out:
# array([-6, '>$50B               ', '$10B-$50B           ',
#        '>$10B               ', 0], dtype=object)

# %%
df1 = df1.drop(['Unnamed: 10'],axis = 1)

# %%
df1
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 0                                                   0        0     0
# 1                               American Express Co.       NY      1
# 2                            First Citizens Banchares      NC      2
# 3                            Wintrust Financial Corp.      IL      3
# 4                                       Zions Bancorp      UT      4
# ..                                                ...      ...   ...
# 92                     Charles Schwab Bk                    NV     0
# 93                     Third FS&LA                          OH     0
# 94  *The bank was formerly known as GE Money Bank,...        0     0
# 95  1 TA = total domestic assets held by the lende...        0     0
# 96  Source: U.S. Small Business Administration, Of...        0     0
#
#    TA Ratio1 TBL Ratio1 Amount ($1,000)  Number      Lender Asset Size  \
# ...

# %%
df1 = df1.drop([0],axis=0)

# %%
df1
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 1                               American Express Co.       NY      1
# 2                            First Citizens Banchares      NC      2
# 3                            Wintrust Financial Corp.      IL      3
# 4                                       Zions Bancorp      UT      4
# 5                             Synovus Financial Corp.      GA      5
# ..                                                ...      ...   ...
# 92                     Charles Schwab Bk                    NV     0
# 93                     Third FS&LA                          OH     0
# 94  *The bank was formerly known as GE Money Bank,...        0     0
# 95  1 TA = total domestic assets held by the lende...        0     0
# 96  Source: U.S. Small Business Administration, Of...        0     0
#
#    TA Ratio1 TBL Ratio1 Amount ($1,000)  Number      Lender Asset Size  \
# 1    0.23829   0.999544        16350038  3603226  >$50B
# ...

# %%
df1['TA Ratio1'] = df1['TA Ratio1'].astype('str')
a=0
count=0
for i in df1['TA Ratio1']:
    try:
        if i != '-':
            i = float(i)
            a+=i
            count+=1
    except ValueError:
        pass
print(a)
print(count)
mean_of_columns = a/count
print(mean_of_columns)
# Out:
# 4.331450537429008
# 92
# 0.04708098410248922

# %%
df1["TA Ratio1"] = df1["TA Ratio1"].replace("-",mean_of_columns)

# %%
df1["CC Amount/TA1"].describe
# Out:
# <bound method NDFrame.describe of 1        0.28
# 2         .
# 3           0
# 4           0
# 5        0.01
#        ...
# 92        .
# 93        .
# 94          0
# 95          0
# 96          0
# Name: CC Amount/TA1, Length: 96, dtype: object>

# %%
df1['CC Amount/TA1'] = df1['CC Amount/TA1'].astype('str')
b=0
count1=0
for i in df1['CC Amount/TA1']:
    try:
        if i != '.':
            i = float(i)
            b+=i
            count1+=1
    except ValueError:
        pass
print(b)
print(count1)
mean_of_columns1 = b/count1
print(mean_of_columns1)
df1["CC Amount/TA1"] = df1["CC Amount/TA1"].replace("    .  ",mean_of_columns1)
# Out:
# 0.9600000000000002
# 49
# 0.01959183673469388

# %%
df1['TBL Ratio1'] = df1['TBL Ratio1'].astype('str')
c=0
count2=0
for i in df1['TBL Ratio1']:
    try:
        if i != '-':
            i = float(i)
            c+=i
            count2+=1
    except ValueError:
        pass
print(c)
print(count2)
mean_of_columns2 = c/count2
print(mean_of_columns2)
df1["TBL Ratio1"] = df1["TBL Ratio1"].replace("-",mean_of_columns2)
# Out:
# 22.10528917207525
# 91
# 0.24291526562720053

# %%
df1['Amount ($1,000)'] = df1['Amount ($1,000)'].astype('str')
d = 0
count3 =0 
for i in df1['Amount ($1,000)']:
    try:
        if i != '-':
            i = int(i)
            d = d+i
            count3+=1
    except ValueError:
        pass
print(d)
print(count3)
mean = d/count3
print(mean)
df1['Amount ($1,000)'] = df1['Amount ($1,000)'].replace("-",mean)
# Out:
# 283446407
# 92
# 3080939.2065217393

# %%
df1['Number '] = df1['Number '].astype('str')
e=0
count4=0
for i in df1['Number ']:
    try:
        if i != '-':
            i = int(i)
            e+=i
            count4+=1
    except ValueError:
        pass
print(e)
print(count4)
mean_of_columns4 = e/count4
print(mean_of_columns4)
df1["Number "] = df1["Number "].replace("-",mean_of_columns4)
# Out:
# 19261287
# 92
# 209361.8152173913

# %%
df1
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 1                               American Express Co.       NY      1
# 2                            First Citizens Banchares      NC      2
# 3                            Wintrust Financial Corp.      IL      3
# 4                                       Zions Bancorp      UT      4
# 5                             Synovus Financial Corp.      GA      5
# ..                                                ...      ...   ...
# 92                     Charles Schwab Bk                    NV     0
# 93                     Third FS&LA                          OH     0
# 94  *The bank was formerly known as GE Money Bank,...        0     0
# 95  1 TA = total domestic assets held by the lende...        0     0
# 96  Source: U.S. Small Business Administration, Of...        0     0
#
#               TA Ratio1           TBL Ratio1 Amount ($1,000)  Number   \
# ...

# %%
df1['Lender Asset Size'] = df1['Lender Asset Size'].replace(['>$50B               ','$10B-$50B           ','>$10B               '],[0,1,2])

# %%
df1
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 1                               American Express Co.       NY      1
# 2                            First Citizens Banchares      NC      2
# 3                            Wintrust Financial Corp.      IL      3
# 4                                       Zions Bancorp      UT      4
# 5                             Synovus Financial Corp.      GA      5
# ..                                                ...      ...   ...
# 92                     Charles Schwab Bk                    NV     0
# 93                     Third FS&LA                          OH     0
# 94  *The bank was formerly known as GE Money Bank,...        0     0
# 95  1 TA = total domestic assets held by the lende...        0     0
# 96  Source: U.S. Small Business Administration, Of...        0     0
#
#               TA Ratio1           TBL Ratio1 Amount ($1,000)  Number   \
# ...

# %%
df1['Name of Lending Institution'] = df1['Name of Lending Institution'].astype('str') 
df1['HQ State'] = df1['HQ State'].astype('str') 
df1['Rank'] = df1['Rank'].astype('int') 
df1['TA Ratio1'] = df1['TA Ratio1'].astype('float') 
df1['TBL Ratio1'] = df1['TBL Ratio1'].astype('float') 
df1['Amount ($1,000)'] = df1['Amount ($1,000)'].astype('float') 
df1['Number '] = df1['Number '].astype('int') 
df1['Lender Asset Size'] = df1['Lender Asset Size'].astype('int') 
df1['CC Amount/TA1'] = df1['CC Amount/TA1'].astype('float')

# %%
df1.dtypes
# Out:
# Name of Lending Institution     object
# HQ State                        object
# Rank                             int32
# TA Ratio1                      float64
# TBL Ratio1                     float64
# Amount ($1,000)                float64
# Number                           int32
# Lender Asset Size                int32
# Amount ($1,000).1              float64
# Number .1                      float64
# Amount ($1,000).2              float64
# Number .2                      float64
# CC Amount/TA1                  float64
# dtype: object

# %%
df1.head()
# Out:
#   Name of Lending Institution HQ State  Rank  TA Ratio1  TBL Ratio1  \
# 1       American Express Co.       NY      1   0.238290    0.999544
# 2    First Citizens Banchares      NC      2   0.187393    0.490830
# 3    Wintrust Financial Corp.      IL      3   0.168999    0.383561
# 4               Zions Bancorp      UT      4   0.117973    0.260577
# 5     Synovus Financial Corp.      GA      5   0.162333    0.381387
#
#    Amount ($1,000)  Number   Lender Asset Size  Amount ($1,000).1  Number .1  \
# 1       16350038.0  3603226                  0         16318089.0  3603088.0
# 2        3914507.0   117702                  1           378394.0   105081.0
# 3        2842793.0   136801                  1           800526.0   126455.0
# 4        6231770.0    52612                  0           526206.0    32973.0
# 5        4227168.0    22675                  1           539666.0     9593.0
#
#    Amount ($1,000).2  Number .2  CC Amount/TA1
# ...
